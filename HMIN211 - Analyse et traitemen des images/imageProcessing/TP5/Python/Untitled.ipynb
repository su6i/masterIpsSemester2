# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
# %ls
# Out:
# 01.pgm        07.pgm        13.pgm        boat.pgm      lena4.pgm
# 02.pgm        08.pgm        14.pgm        girl.pgm      sailboat.pgm
# 03.pgm        09.pgm        15.pgm        gradient.pgm  tiffany.pgm
# 04.pgm        10.pgm        amir.pgm      house.pgm
# 05.pgm        11.pgm        baboon.pgm    lena.pgm
# 06.pgm        12.pgm        black.pgm     lena256.pgm

# %%
img = cv.imread('10.pgm',cv.IMREAD_GRAYSCALE)
sobelx = cv.Sobel(img,cv.CV_64F,1,0,ksize=5)
sobely = cv.Sobel(img,cv.CV_64F,0,1,ksize=5)
abs_grad_x = cv.convertScaleAbs(sobelx)
abs_grad_y = cv.convertScaleAbs(sobely)
modgrad = cv.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)

# %%
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(modgrad,cmap = 'gray')
plt.title('Module gradient'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
